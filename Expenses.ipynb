# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mysql-connector-python in c:\users\likithkumar\appdata\roaming\python\python313\site-packages (9.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
from datetime import datetime

# MySQL Connection
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Lk225@",
    database="expense_db"
)

cursor = conn.cursor()


# Add Expense
def add_expense():
    amount = float(input("Enter amount: "))
    category = input("Enter category: ")
    date = input("Enter date (YYYY-MM-DD) or press Enter for today: ")
    if date == "":
        date = datetime.today().strftime("%Y-%m-%d")
    note = input("Enter note: ")

    query = "INSERT INTO expenses (amount, category, date, note) VALUES (%s, %s, %s, %s)"
    values = (amount, category, date, note)

    cursor.execute(query, values)
    conn.commit()
    print("Expense added successfully!")


# View All Expenses
def view_expenses():
    cursor.execute("SELECT * FROM expenses")
    rows = cursor.fetchall()

    print("\n---- All Expenses ----")
    for row in rows:
        print(row)


# Update Expense
def update_expense():
    expense_id = int(input("Enter Expense ID to update: "))
    new_amount = float(input("Enter new amount: "))
    new_category = input("Enter new category: ")
    new_note = input("Enter new note: ")

    query = """
    UPDATE expenses SET amount=%s, category=%s, note=%s WHERE id=%s
    """
    values = (new_amount, new_category, new_note, expense_id)

    cursor.execute(query, values)
    conn.commit()
    print("Expense updated successfully!")


# Delete Expense
def delete_expense():
    expense_id = int(input("Enter Expense ID to delete: "))

    query = "DELETE FROM expenses WHERE id=%s"
    cursor.execute(query, (expense_id,))
    conn.commit()

    print("Expense deleted successfully!")


# Main Menu
while True:
    print("\n==== Expense Tracker (MySQL) ====")
    print("1. Add Expense")
    print("2. View Expenses")
    print("3. Update Expense")
    print("4. Delete Expense")
    print("5. Exit")

    choice = input("Choose an option: ")

    if choice == "1":
        add_expense()
    elif choice == "2":
        view_expenses()
    elif choice == "3":
        update_expense()
    elif choice == "4":
        delete_expense()
        
    elif choice == "5":
        print("Goodbye!")
        break
    else:
        print("Invalid choice! Try again.")
# Out:
# ==== Expense Tracker (MySQL) ====
# 1. Add Expense
# 2. View Expenses
# 3. Update Expense
# 4. Delete Expense
# 5. Exit
# Choose an option:  1
# Enter amount:  50
# Enter category:  food
# Enter date (YYYY-MM-DD) or press Enter for today:  2004-09-12
# Enter note:  jai
# Expense added successfully!
#
# ==== Expense Tracker (MySQL) ====
# 1. Add Expense
# 2. View Expenses
# 3. Update Expense
# 4. Delete Expense
# 5. Exit
# Choose an option:  2
# ---- All Expenses ----
# (1, 250.0, 'food', datetime.date(2025, 12, 11), 'launch at restaraunt')
# (2, 50.0, 'food', datetime.date(2004, 9, 12), 'jai')
#
# ==== Expense Tracker (MySQL) ====
# 1. Add Expense
# 2. View Expenses
# 3. Update Expense
# 4. Delete Expense
# 5. Exit
# Choose an option:  1000
# Invalid choice! Try again.
#
# ==== Expense Tracker (MySQL) ====
# 1. Add Expense
# 2. View Expenses
# 3. Update Expense
# 4. Delete Expense
# 5. Exit
# Choose an option:  1
# Enter amount:  1000
# Enter category:  shopping
# Enter date (YYYY-MM-DD) or press Enter for today:  2025-1-10
# Enter note:  Bought shoes
# Expense added successfully!
#
# ==== Expense Tracker (MySQL) ====
# 1. Add Expense
# 2. View Expenses
# 3. Update Expense
# 4. Delete Expense
# 5. Exit
# Choose an option:  1
# Enter amount:  150
# Enter category:  travel
# Enter date (YYYY-MM-DD) or press Enter for today:  2025-1-11
# Enter note:  auto to office
# Expense added successfully!
#
# ==== Expense Tracker (MySQL) ====
# 1. Add Expense
# 2. View Expenses
# 3. Update Expense
# 4. Delete Expense
# 5. Exit
# Choose an option:  1
# Enter amount:  2000
# Enter category:  rent
# Enter date (YYYY-MM-DD) or press Enter for today:  2025-1-1
# Enter note:  room rent for jan
# Expense added successfully!
#
# ==== Expense Tracker (MySQL) ====
# 1. Add Expense
# 2. View Expenses
# 3. Update Expense
# 4. Delete Expense
# 5. Exit
# Choose an option:  1
# Enter amount:  80
# Enter category:  snacks
# Enter date (YYYY-MM-DD) or press Enter for today:  2025-1-12
# Enter note:  tea & biscuit
# Expense added successfully!
#
# ==== Expense Tracker (MySQL) ====
# 1. Add Expense
# 2. View Expenses
# 3. Update Expense
# 4. Delete Expense
# 5. Exit
# Choose an option:  1
